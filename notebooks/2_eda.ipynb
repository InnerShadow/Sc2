# %%
# %cd './..'
import pandas as pd
# Out:
# /home/masikol/main/Sc2

# %%
df = pd.read_csv('./data/dataset.csv', sep = ';')
df
# Out:
#              date     player player_race  player_score  player_id   opponent  \
# 0      01/18/2026      Rogue           Z           2.0     1662.0   Oliveira
# 1      01/18/2026        MMA           T           0.0       28.0        DRG
# 2      01/18/2026       herO           P           4.0      233.0     Reynor
# 3      01/18/2026       Clem           T           2.0     5878.0     Reynor
# 4      01/18/2026       herO           P           3.0      233.0      Solar
# ...           ...        ...         ...           ...        ...        ...
# 23984  01/13/2025        PiG           Z           2.0      246.0    ieLLiMo
# 23985  01/13/2025       Mute           P           2.0    18372.0    Patches
# 23986  01/13/2025      Lemon           P           2.0    17623.0  MrNibbles
# 23987  01/13/2025  Shameless           P           2.0    20769.0       Kyto
# 23988  01/13/2025       Matt           Z           2.0    24179.0     Gemini
#
#       opponent_race  opponent_score  opponent_id score_match tier  \
# 0                 T             0.0      10115.0         2–0    S
# 1                 Z             2.0          4.0         0–2    S
# 2                 Z             3.0       5414.0         4–3    S
# 3                 Z             3.0       5414.0         2–3    S
# 4                 Z             1.0       1793.0         3–1    S
# ...             ...             ...          ...         ...  ...
# 23984             P             0.0      20150.0         2–0    B
# 23985             T             0.0      22423.0         2–0    B
# 23986             P             0.0      25444.0         2–0    B
# 23987             T             0.0      24462.0         2–0    B
# 23988             P             1.0       6306.0         2–1    B
#
#                                              url  \
# 0      http://aligulac.com/results/events/156009
# 1      http://aligulac.com/results/events/156009
# 2      http://aligulac.com/results/events/156009
# 3      http://aligulac.com/results/events/156009
# 4      http://aligulac.com/results/events/156009
# ...                                          ...
# 23984  http://aligulac.com/results/events/149981
# 23985  http://aligulac.com/results/events/149981
# 23986  http://aligulac.com/results/events/149981
# 23987  http://aligulac.com/results/events/149981
# 23988  http://aligulac.com/results/events/149981
#
#                                               tournament
# 0      https://liquipedia.net/starcraft2/Thunderfire_...
# 1      https://liquipedia.net/starcraft2/Thunderfire_...
# 2      https://liquipedia.net/starcraft2/Thunderfire_...
# 3      https://liquipedia.net/starcraft2/Thunderfire_...
# 4      https://liquipedia.net/starcraft2/Thunderfire_...
# ...                                                  ...
# 23984  https://liquipedia.net/starcraft2/PiGosaur_Mon...
# 23985  https://liquipedia.net/starcraft2/PiGosaur_Mon...
# 23986  https://liquipedia.net/starcraft2/PiGosaur_Mon...
# 23987  https://liquipedia.net/starcraft2/PiGosaur_Mon...
# 23988  https://liquipedia.net/starcraft2/PiGosaur_Mon...
#
# [23989 rows x 13 columns]

# %%
df['date'] = pd.to_datetime(df['date'])
df
# Out:
#             date     player player_race  player_score  player_id   opponent  \
# 0     2026-01-18      Rogue           Z           2.0     1662.0   Oliveira
# 1     2026-01-18        MMA           T           0.0       28.0        DRG
# 2     2026-01-18       herO           P           4.0      233.0     Reynor
# 3     2026-01-18       Clem           T           2.0     5878.0     Reynor
# 4     2026-01-18       herO           P           3.0      233.0      Solar
# ...          ...        ...         ...           ...        ...        ...
# 23984 2025-01-13        PiG           Z           2.0      246.0    ieLLiMo
# 23985 2025-01-13       Mute           P           2.0    18372.0    Patches
# 23986 2025-01-13      Lemon           P           2.0    17623.0  MrNibbles
# 23987 2025-01-13  Shameless           P           2.0    20769.0       Kyto
# 23988 2025-01-13       Matt           Z           2.0    24179.0     Gemini
#
#       opponent_race  opponent_score  opponent_id score_match tier  \
# 0                 T             0.0      10115.0         2–0    S
# 1                 Z             2.0          4.0         0–2    S
# 2                 Z             3.0       5414.0         4–3    S
# 3                 Z             3.0       5414.0         2–3    S
# 4                 Z             1.0       1793.0         3–1    S
# ...             ...             ...          ...         ...  ...
# 23984             P             0.0      20150.0         2–0    B
# 23985             T             0.0      22423.0         2–0    B
# 23986             P             0.0      25444.0         2–0    B
# 23987             T             0.0      24462.0         2–0    B
# 23988             P             1.0       6306.0         2–1    B
#
#                                              url  \
# 0      http://aligulac.com/results/events/156009
# 1      http://aligulac.com/results/events/156009
# 2      http://aligulac.com/results/events/156009
# 3      http://aligulac.com/results/events/156009
# 4      http://aligulac.com/results/events/156009
# ...                                          ...
# 23984  http://aligulac.com/results/events/149981
# 23985  http://aligulac.com/results/events/149981
# 23986  http://aligulac.com/results/events/149981
# 23987  http://aligulac.com/results/events/149981
# 23988  http://aligulac.com/results/events/149981
#
#                                               tournament
# 0      https://liquipedia.net/starcraft2/Thunderfire_...
# 1      https://liquipedia.net/starcraft2/Thunderfire_...
# 2      https://liquipedia.net/starcraft2/Thunderfire_...
# 3      https://liquipedia.net/starcraft2/Thunderfire_...
# 4      https://liquipedia.net/starcraft2/Thunderfire_...
# ...                                                  ...
# 23984  https://liquipedia.net/starcraft2/PiGosaur_Mon...
# 23985  https://liquipedia.net/starcraft2/PiGosaur_Mon...
# 23986  https://liquipedia.net/starcraft2/PiGosaur_Mon...
# 23987  https://liquipedia.net/starcraft2/PiGosaur_Mon...
# 23988  https://liquipedia.net/starcraft2/PiGosaur_Mon...
#
# [23989 rows x 13 columns]

# %%
df = df.drop(columns = ['player_id', 'opponent_id', 'score_match', 'url', 'tournament'])
df
# Out:
#             date     player player_race  player_score   opponent  \
# 0     2026-01-18      Rogue           Z           2.0   Oliveira
# 1     2026-01-18        MMA           T           0.0        DRG
# 2     2026-01-18       herO           P           4.0     Reynor
# 3     2026-01-18       Clem           T           2.0     Reynor
# 4     2026-01-18       herO           P           3.0      Solar
# ...          ...        ...         ...           ...        ...
# 23984 2025-01-13        PiG           Z           2.0    ieLLiMo
# 23985 2025-01-13       Mute           P           2.0    Patches
# 23986 2025-01-13      Lemon           P           2.0  MrNibbles
# 23987 2025-01-13  Shameless           P           2.0       Kyto
# 23988 2025-01-13       Matt           Z           2.0     Gemini
#
#       opponent_race  opponent_score tier
# 0                 T             0.0    S
# 1                 Z             2.0    S
# 2                 Z             3.0    S
# 3                 Z             3.0    S
# 4                 Z             1.0    S
# ...             ...             ...  ...
# 23984             P             0.0    B
# 23985             T             0.0    B
# 23986             P             0.0    B
# 23987             T             0.0    B
# 23988             P             1.0    B
#
# [23989 rows x 8 columns]

# %%
print(df.shape)
df = df[df['player_score'] != df['opponent_score']].reset_index(drop = True)
print(df.shape)
# Out:
# (23989, 8)
# (23293, 8)

# %%
add_rows = []

for it, row in df.iterrows():
    add_rows.append({
        'date' : row['date'],
        'player' : row['opponent'],
        'player_race' : row['opponent_race'],
        'player_score' : row['opponent_score'],
        'opponent' : row['player'],
        'opponent_race' : row['player_race'],
        'opponent_score' : row['player_score'],
        'tier' : row['tier']
    })
# end for

df_add = pd.DataFrame(add_rows)
df = pd.concat([df, df_add]).reset_index(drop = True)
df
# Out:
#             date     player player_race  player_score   opponent  \
# 0     2026-01-18      Rogue           Z           2.0   Oliveira
# 1     2026-01-18        MMA           T           0.0        DRG
# 2     2026-01-18       herO           P           4.0     Reynor
# 3     2026-01-18       Clem           T           2.0     Reynor
# 4     2026-01-18       herO           P           3.0      Solar
# ...          ...        ...         ...           ...        ...
# 46581 2025-01-13    ieLLiMo           P           0.0        PiG
# 46582 2025-01-13    Patches           T           0.0       Mute
# 46583 2025-01-13  MrNibbles           P           0.0      Lemon
# 46584 2025-01-13       Kyto           T           0.0  Shameless
# 46585 2025-01-13     Gemini           P           1.0       Matt
#
#       opponent_race  opponent_score tier
# 0                 T             0.0    S
# 1                 Z             2.0    S
# 2                 Z             3.0    S
# 3                 Z             3.0    S
# 4                 Z             1.0    S
# ...             ...             ...  ...
# 46581             Z             2.0    B
# 46582             P             2.0    B
# 46583             P             2.0    B
# 46584             P             2.0    B
# 46585             Z             2.0    B
#
# [46586 rows x 8 columns]

# %%
df['player'].value_counts()
# Out:
# player
# ByuN            1252
# Clem            1214
# Solar           1029
# MaxPax          1002
# herO             987
#                 ...
# Xlebuwek           1
# AztecDaddyTV       1
# xVoid              1
# Senna              1
# Soita              1
# Name: count, Length: 1322, dtype: int64

# %%
df[(df['player'] == 'Maya') | (df['opponent'] == 'Maya')]
# Out:
#             date      player player_race  player_score    opponent  \
# 16591 2025-08-18       Solar           Z           2.0        Maya
# 17493 2025-07-14  Bulmyeolja           P           2.0        Maya
# 17494 2025-07-14      Luolis           T           0.0        Maya
# 17496 2025-07-14      RosscO           P           0.0        Maya
# 39884 2025-08-18        Maya           T           1.0       Solar
# 40786 2025-07-14        Maya           T           0.0  Bulmyeolja
# 40787 2025-07-14        Maya           T           2.0      Luolis
# 40789 2025-07-14        Maya           T           2.0      RosscO
#
#       opponent_race  opponent_score tier
# 16591             T             1.0    B
# 17493             T             0.0    B
# 17494             T             2.0    B
# 17496             T             2.0    B
# 39884             Z             2.0    B
# 40786             P             2.0    B
# 40787             T             0.0    B
# 40789             P             0.0    B

# %%
df['best_of'] = 2 * df[['player_score', 'opponent_score']].max(axis = 1) - 1
df
# Out:
#             date     player player_race  player_score   opponent  \
# 0     2026-01-18      Rogue           Z           2.0   Oliveira
# 1     2026-01-18        MMA           T           0.0        DRG
# 2     2026-01-18       herO           P           4.0     Reynor
# 3     2026-01-18       Clem           T           2.0     Reynor
# 4     2026-01-18       herO           P           3.0      Solar
# ...          ...        ...         ...           ...        ...
# 46581 2025-01-13    ieLLiMo           P           0.0        PiG
# 46582 2025-01-13    Patches           T           0.0       Mute
# 46583 2025-01-13  MrNibbles           P           0.0      Lemon
# 46584 2025-01-13       Kyto           T           0.0  Shameless
# 46585 2025-01-13     Gemini           P           1.0       Matt
#
#       opponent_race  opponent_score tier  best_of
# 0                 T             0.0    S      3.0
# 1                 Z             2.0    S      3.0
# 2                 Z             3.0    S      7.0
# 3                 Z             3.0    S      5.0
# 4                 Z             1.0    S      5.0
# ...             ...             ...  ...      ...
# 46581             Z             2.0    B      3.0
# 46582             P             2.0    B      3.0
# 46583             P             2.0    B      3.0
# 46584             P             2.0    B      3.0
# 46585             Z             2.0    B      3.0
#
# [46586 rows x 9 columns]

# %%
df['player_win_prc'] = (df['player_score'] / (df['player_score'] + df['opponent_score'])).round(4)
df
# Out:
#             date     player player_race  player_score   opponent  \
# 0     2026-01-18      Rogue           Z           2.0   Oliveira
# 1     2026-01-18        MMA           T           0.0        DRG
# 2     2026-01-18       herO           P           4.0     Reynor
# 3     2026-01-18       Clem           T           2.0     Reynor
# 4     2026-01-18       herO           P           3.0      Solar
# ...          ...        ...         ...           ...        ...
# 46581 2025-01-13    ieLLiMo           P           0.0        PiG
# 46582 2025-01-13    Patches           T           0.0       Mute
# 46583 2025-01-13  MrNibbles           P           0.0      Lemon
# 46584 2025-01-13       Kyto           T           0.0  Shameless
# 46585 2025-01-13     Gemini           P           1.0       Matt
#
#       opponent_race  opponent_score tier  best_of  player_win_prc
# 0                 T             0.0    S      3.0          1.0000
# 1                 Z             2.0    S      3.0          0.0000
# 2                 Z             3.0    S      7.0          0.5714
# 3                 Z             3.0    S      5.0          0.4000
# 4                 Z             1.0    S      5.0          0.7500
# ...             ...             ...  ...      ...             ...
# 46581             Z             2.0    B      3.0          0.0000
# 46582             P             2.0    B      3.0          0.0000
# 46583             P             2.0    B      3.0          0.0000
# 46584             P             2.0    B      3.0          0.0000
# 46585             Z             2.0    B      3.0          0.3333
#
# [46586 rows x 10 columns]

# %%
df['target'] = (df['player_score'] > df['opponent_score']).astype(int)
df
# Out:
#             date     player player_race  player_score   opponent  \
# 0     2026-01-18      Rogue           Z           2.0   Oliveira
# 1     2026-01-18        MMA           T           0.0        DRG
# 2     2026-01-18       herO           P           4.0     Reynor
# 3     2026-01-18       Clem           T           2.0     Reynor
# 4     2026-01-18       herO           P           3.0      Solar
# ...          ...        ...         ...           ...        ...
# 46581 2025-01-13    ieLLiMo           P           0.0        PiG
# 46582 2025-01-13    Patches           T           0.0       Mute
# 46583 2025-01-13  MrNibbles           P           0.0      Lemon
# 46584 2025-01-13       Kyto           T           0.0  Shameless
# 46585 2025-01-13     Gemini           P           1.0       Matt
#
#       opponent_race  opponent_score tier  best_of  player_win_prc  target
# 0                 T             0.0    S      3.0          1.0000       1
# 1                 Z             2.0    S      3.0          0.0000       0
# 2                 Z             3.0    S      7.0          0.5714       1
# 3                 Z             3.0    S      5.0          0.4000       0
# 4                 Z             1.0    S      5.0          0.7500       1
# ...             ...             ...  ...      ...             ...     ...
# 46581             Z             2.0    B      3.0          0.0000       0
# 46582             P             2.0    B      3.0          0.0000       0
# 46583             P             2.0    B      3.0          0.0000       0
# 46584             P             2.0    B      3.0          0.0000       0
# 46585             Z             2.0    B      3.0          0.3333       0
#
# [46586 rows x 11 columns]

# %%
from dateutil.relativedelta import relativedelta

df = df.sort_values(['player', 'date']).reset_index(drop = True)
df
# Out:
#             date       player player_race  player_score opponent  \
# 0     2025-08-16         5GTV           T           0.0  Maxxima
# 1     2019-07-23         ACID           T           0.0    Shino
# 2     2019-07-23         ACID           T           1.0      ArT
# 3     2019-12-14  AGIANTSMURF           P           0.0    avilo
# 4     2019-12-14  AGIANTSMURF           P           0.0      Rob
# ...          ...          ...         ...           ...      ...
# 46581 2025-10-31         阳光人族           T           2.0     欲沐东湖
# 46582 2025-05-31        雨何时会停           T           0.0   Oriana
# 46583 2025-05-31           鹿乃           Z           0.0      大刚猛
# 46584 2025-10-11           밀면           T           0.0     ByuN
# 46585 2025-01-14          풍등이           T           0.0  Creator
#
#       opponent_race  opponent_score tier  best_of  player_win_prc  target
# 0                 P             2.0    B      3.0          0.0000       0
# 1                 Z             2.0    A      3.0          0.0000       0
# 2                 P             2.0    A      3.0          0.3333       0
# 3                 T             2.0    A      3.0          0.0000       0
# 4                 P             2.0    A      3.0          0.0000       0
# ...             ...             ...  ...      ...             ...     ...
# 46581             P             1.0    B      3.0          0.6667       1
# 46582             T             2.0    B      3.0          0.0000       0
# 46583             P             2.0    B      3.0          0.0000       0
# 46584             T             2.0    B      3.0          0.0000       0
# 46585             P             2.0    B      3.0          0.0000       0
#
# [46586 rows x 11 columns]

# %%
from tqdm import tqdm

def add_winrate_features(player_df):
    player_df = player_df.copy()

    for m in range(1, 13):
        for race in ['P', 'T', 'Z']:
            col_match = f'wr_match_{race}_{m}m'
            col_game = f'wr_game_{race}_{m}m'

            values_match = []
            value_games = []

            for idx, row in player_df.iterrows():
                end = row['date']
                start = end - relativedelta(months = m)

                window = player_df[
                    (player_df['date'] < end) &
                    (player_df['date'] >= start) &
                    (player_df['opponent_race'] == race)
                ]

                values_match.append(window['player_win_prc'].mean())
                value_games.append(window['target'].mean())
            # end for

            player_df[col_match] = values_match
            player_df[col_game] = value_games
        # end for
    # end for

    return player_df
# end def

df = (
    df
    .groupby('player', group_keys = False)
    .apply(add_winrate_features)
)

# %%
from tqdm import tqdm

def add_winrate_history_features(player_df):
    player_df = player_df.copy()

    for m in range(1, 13):
        col_match = f'wr_match_history_{m}m'
        col_game = f'wr_game_history_{m}m'

        values_match = []
        value_games = []

        for idx, row in player_df.iterrows():
            oponent = row['opponent']
            end = row['date']
            start = end - relativedelta(months = m)

            window = player_df[
                (player_df['date'] < end) &
                (player_df['date'] >= start) &
                (player_df['opponent'] == oponent)
            ]

            values_match.append(window['player_win_prc'].mean())
            value_games.append(window['target'].mean())
        # end for

        player_df[col_match] = values_match
        player_df[col_game] = value_games
    # end for

    return player_df
# end def

df = (
    df
    .groupby('player', group_keys = False)
    .apply(add_winrate_features)
)

# %%
df

# %%
import numpy as np

periods = [f"{i}m" for i in range(1, 13)]
race_mapping = {}

for period in periods:
    for race in ['P', 'T', 'Z']:
        race_mapping[(period, 'match', race)] = f'wr_match_{race}_{period}'
        race_mapping[(period, 'game', race)] = f'wr_game_{race}_{period}'
    # end for
# end for

def get_wr_by_race(row, period, stat_type='match'):
    opponent_race = row['opponent_race']
    
    if opponent_race == 'R':
        return np.nan
    # end if
    
    col_name = race_mapping.get((period, stat_type, opponent_race))
    
    if col_name and col_name in row:
        return row[col_name]
    # end if
    return np.nan
# end def

for period in periods:
    df[f'wr_match_vs_opponent_{period}'] = df.apply(
        lambda x: get_wr_by_race(x, period, 'match'), axis=1
    )
    
    df[f'wr_game_vs_opponent_{period}'] = df.apply(
        lambda x: get_wr_by_race(x, period, 'game'), axis=1
    )
# end for

for period in periods:
    conditions = [
        df['opponent_race'] == 'P',
        df['opponent_race'] == 'T',
        df['opponent_race'] == 'Z'
    ]
    
    choices_match = [
        df[f'wr_match_P_{period}'],
        df[f'wr_match_T_{period}'],
        df[f'wr_match_Z_{period}']
    ]
    
    choices_game = [
        df[f'wr_game_P_{period}'],
        df[f'wr_game_T_{period}'],
        df[f'wr_game_Z_{period}']
    ]
    
    df[f'wr_match_vs_opponent_race_{period}'] = np.select(
        conditions, choices_match, default=np.nan
    )
    df[f'wr_game_vs_opponent_race_{period}'] = np.select(
        conditions, choices_game, default=np.nan
    )
# end for

df

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

X_train, X_test, y_train, y_test = train_test_split(
    df.drop(columns = ['player_score', 'opponent_score', 'player_win_prc', 'target', 'date']),
    df['target'],
    test_size = 0.2
)

model = XGBClassifier(n_jobs = -1, enable_categorical = True)
model.fit(X = X_train, y = y_train)
roc_auc_score(y_test, model.predict_proba(X_test)[:, 1])

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, model.predict(X_test)))

# %%
print(classification_report(y_train, model.predict(X_train)))
